# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('/groups/turaga/home/kimb2/compound-ray/python-examples/alias-demonstration/output/generated-data/alias-demonstration/-2_test-image-100-samples.ppm')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = Image.open('/groups/turaga/home/kimb2/compound-ray/python-examples/alias-demonstration/output/generated-data/alias-demonstration/0_test-image-100-samples.ppm')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = Image.open('/groups/turaga/home/kimb2/compound-ray/python-examples/alias-demonstration/output/generated-data/alias-demonstration/2_test-image-100-samples.ppm')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = Image.open('/groups/turaga/home/kimb2/compound-ray/python-examples/alias-demonstration/output/generated-data/alias-demonstration/3_test-image-100-samples.ppm')
plt.imshow(img)
plt.axis('off')
plt.show()
